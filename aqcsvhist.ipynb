# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import requests

# %%
data_url = 'aq.csv'

data = pd.read_csv(data_url)

# %%
print(data)
# Out:
#             Time  0.3  0.5  1.0  2.5  5.0  10
# 0   1.771026e+09  393   98    7    0    0   0
# 1   1.771026e+09  393   98    7    0    0   0
# 2   1.771026e+09  390   96    7    0    0   0
# 3   1.771026e+09  390   96    7    0    0   0
# 4   1.771026e+09  390   96    7    0    0   0
# 5   1.771026e+09  390   96    6    0    0   0
# 6   1.771026e+09  390   96    6    0    0   0
# 7   1.771026e+09  390   96    6    0    0   0
# 8   1.771026e+09  381   98    5    0    0   0
# 9   1.771026e+09  381   98    5    0    0   0
# 10  1.771026e+09  381   98    5    0    0   0

# %%
plt.hist(data["0.3"],bins=5) #used 0.3 data instead of 2.5 because 2.5 had only zero values
# Out:
# (array([3., 0., 0., 6., 2.]),
#  array([381. , 383.4, 385.8, 388.2, 390.6, 393. ]),
#  <BarContainer object of 5 artists>)
